# %% [markdown]
# <a href="https://colab.research.google.com/github/asaane88/Arvind-Saane/blob/master/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from keras import Sequential
from keras.layers import Dense
from keras.optimizers import SGD

# %%
from sklearn import datasets

# %%
x,y = datasets.make_moons(n_samples=1000, random_state=5)
color=["steelblue" if label == 1 else "darkred" for label in y]

# %%
print(x.shape)
print(y.shape)
# Out:
# (1000, 2)
# (1000,)

# %%
plt.scatter(x[:,0], x[:,1], color=color)

# %%
model = Sequential()
model.add(Dense(10, input_shape=(2,), activation="relu"))
model.add(Dense(15, activation="relu"))
model.add(Dense(18, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

sgd=SGD(lr=0.1)
model.compile(loss="binary_crossentropy", optimizer="sgd", metrics=["accuracy"])
model.fit(x,y,epochs=2000, verbose=1 )
# Out:
# Epoch 1/2000
# 1000/1000 [==============================] - 0s 426us/step - loss: 0.7227 - acc: 0.3220
# Epoch 2/2000
# 1000/1000 [==============================] - 0s 49us/step - loss: 0.7003 - acc: 0.4720
# Epoch 3/2000
# 1000/1000 [==============================] - 0s 36us/step - loss: 0.6826 - acc: 0.6550
# Epoch 4/2000
# 1000/1000 [==============================] - 0s 39us/step - loss: 0.6658 - acc: 0.6960
# Epoch 5/2000
# 1000/1000 [==============================] - 0s 39us/step - loss: 0.6507 - acc: 0.7060
# Epoch 6/2000
# 1000/1000 [==============================] - 0s 37us/step - loss: 0.6351 - acc: 0.7050
# Epoch 7/2000
# 1000/1000 [==============================] - 0s 43us/step - loss: 0.6198 - acc: 0.7080
# Epoch 8/2000
# 1000/1000 [==============================] - 0s 38us/step - loss: 0.6047 - acc: 0.7150
# Epoch 9/2000
# 1000/1000 [==============================] - 0s 39us/step - loss: 0.5898 - acc: 0.7210
# Epoch 10/2000
# ...

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x,y,model)
